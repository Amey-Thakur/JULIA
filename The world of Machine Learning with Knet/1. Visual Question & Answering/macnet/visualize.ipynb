# %% [markdown]
# # Visual Q&A Demo

# %% [markdown]
# ## Setup
# 1-Installs required packages
# 2-Downloads sample data and a pretrained model.

# %%
using Pkg; Pkg.activate("."); Pkg.instantiate(); #install required packages
include("demosetup.jl") 
include("src/main.jl")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Demo setup is completed
# ┌ Info: Recompiling stale cache file /Users/ekin/.julia/compiled/v1.1/Knet/f4vSz.ji for Knet [1902f260-5fb4-5aff-8c31-6271790ab950]
# └ @ Base loading.jl:1184
# ┌ Info: Recompiling stale cache file /Users/ekin/.julia/compiled/v1.1/KnetLayers/ZXBRh.ji for KnetLayers [80bfaf46-ad8a-11e8-19eb-a135e382307b]
# └ @ Base loading.jl:1184
# scalepixel (generic function with 1 method)

# %% [markdown]
# ## Initialization
# 1-Loads the sample demo data (image features,questions,vocabulary).
#     * w2i : words to one-hot index   : w2i["cube"] = 30
#     * a2i : answer to one-hot index  : a2i["gray"] = 8
#     * i2w : one-hot index to words   : i2w[2] = "Are"
#     * i2a : one-hot index to answers : i2a[5] = "large"
# 2-Loads the pretrained model, and its hyper-parameters `o`.

# %%
feats,qstsns,(w2i,a2i,i2w,i2a) = loadDemoData("data/demo/");
_,Mrun,o = loadmodel("models/macnet2.jld2";onlywrun=true);
value(params(Mrun)[1]) isa Array ? KnetLayers.settype!(Array) : KnetLayers.settype!(KnetArray)
# Out:
# Loading demo features ...
# Loading demo questions ...
# Loading dictionaries ...
# Array{Float32,N} where N

# %% [markdown]
# ## Sample Data
# 1-Randomly selects (question,image) pair from the sample data
# 2-Make predictions for the question and checks whether the prediction is correct

# %%
rnd        = rand(1:length(qstsns)) # try 41
inst       = qstsns[rnd]
feat       = arrtype(feats[:,:,:,rnd:rnd])
question   = Array{Int}(inst[2])
answer     = inst[3];
family     = inst[4];
results,prediction,interoutputs = singlerun(Mrun,feat,question;p=o[:p],selfattn=o[:selfattn],gating=o[:gating]);
answer==prediction[1]
# Out:
# true

# %%
interoutputs,prediction[1],answer
# Out:
# (Any[[8], [8], [23], [23], [23], [23], [23], [23], [23], [23], [10], [10]], 10, 10)

# %%
img = load("data/demo/CLEVR_v1.0/images/val/$(inst[1])")
# Out:
# 320×480 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(0.416,0.416,0.416,1.0)  …  RGBA{N0f8}(0.4,0.4,0.4,1.0)
#  RGBA{N0f8}(0.412,0.412,0.408,1.0)     RGBA{N0f8}(0.404,0.404,0.404,1.0)
#  RGBA{N0f8}(0.416,0.416,0.412,1.0)     RGBA{N0f8}(0.4,0.4,0.4,1.0)
#  RGBA{N0f8}(0.412,0.412,0.408,1.0)     RGBA{N0f8}(0.4,0.4,0.4,1.0)
#  RGBA{N0f8}(0.412,0.412,0.408,1.0)     RGBA{N0f8}(0.396,0.396,0.396,1.0)
#  RGBA{N0f8}(0.416,0.416,0.416,1.0)  …  RGBA{N0f8}(0.404,0.404,0.404,1.0)
#  RGBA{N0f8}(0.416,0.416,0.416,1.0)     RGBA{N0f8}(0.404,0.4,0.4,1.0)
#  RGBA{N0f8}(0.416,0.416,0.416,1.0)     RGBA{N0f8}(0.404,0.404,0.404,1.0)
#  RGBA{N0f8}(0.412,0.412,0.412,1.0)     RGBA{N0f8}(0.392,0.392,0.392,1.0)
#  RGBA{N0f8}(0.412,0.412,0.412,1.0)     RGBA{N0f8}(0.396,0.396,0.396,1.0)
#  RGBA{N0f8}(0.412,0.412,0.412,1.0)  …  RGBA{N0f8}(0.4,0.4,0.4,1.0)
#  RGBA{N0f8}(0.412,0.412,0.412,1.0)     RGBA{N0f8}(0.404,0.4,0.4,1.0)
#  RGBA{N0f8}(0.416,0.416,0.416,1.0)     RGBA{N0f8}(0.396,0.396,0.396,1.0)
#  ⋮                                  ⋱
#  RGBA{N0f8}(0.459,0.455,0.451,1.0)     RGBA{N0f8}(0.557,0.549,0.533,1.0)
#  RGBA{N0f8}(0.459,0.455,0.451,1.0)     RGBA{N0f8}(0.557,0.549,0.533,1.0)
#  RGBA{N0f8}(0.455,0.455,0.451,1.0)  …  RGBA{N0f8}(0.561,0.553,0.537,1.0)
#  RGBA{N0f8}(0.455,0.451,0.451,1.0)     RGBA{N0f8}(0.561,0.553,0.537,1.0)
#  RGBA{N0f8}(0.459,0.455,0.451,1.0)     RGBA{N0f8}(0.561,0.549,0.533,1.0)
#  RGBA{N0f8}(0.455,0.451,0.447,1.0)     RGBA{N0f8}(0.561,0.553,0.537,1.0)
#  RGBA{N0f8}(0.455,0.451,0.451,1.0)     RGBA{N0f8}(0.565,0.553,0.537,1.0)
#  RGBA{N0f8}(0.459,0.455,0.451,1.0)  …  RGBA{N0f8}(0.561,0.553,0.537,1.0)
#  RGBA{N0f8}(0.459,0.455,0.451,1.0)     RGBA{N0f8}(0.561,0.553,0.537,1.0)
#  RGBA{N0f8}(0.455,0.451,0.451,1.0)     RGBA{N0f8}(0.565,0.557,0.541,1.0)
#  RGBA{N0f8}(0.455,0.451,0.447,1.0)     RGBA{N0f8}(0.565,0.557,0.541,1.0)
#  RGBA{N0f8}(0.455,0.451,0.447,1.0)     RGBA{N0f8}(0.565,0.557,0.541,1.0)

# %%
textq  = i2w[question];
println("Question: ",join(textq," "))
texta  = i2a[answer];
println("Answer: $(texta)\nPrediction: $(i2a[prediction]) ")
# Out:
# Question: What is the color of the other small rubber thing that is the same shape as the small red thing ?
# Answer: blue
# Prediction: blue

# %% [markdown]
# ## User Data
# You can enter your own question about the image and test whether the prediction is correct

# %%
userinput = readline(stdin)
words = split(userinput) # tokenize(userinput)
question = [get!(w2i,wr,1) for wr in words]
results,prediction = singlerun(Mrun,feat,question;p=o[:p],selfattn=o[:selfattn],gating=o[:gating]);
println("Question: $(join(i2w[question]," "))")
println("Prediction: $(i2a[prediction])")
# Out:
# stdin> What is the color of the other small rubber thing that is the same shape as the small red thing ?
# Question: What is the color of the other small rubber thing that is the same shape as the small red thing ?
# Prediction: blue

# %% [markdown]
# ## Visualize
# `visualize` function visualizes attention maps for each time step of the mac network

# %%
visualize(img,results;p=o[:p])
# Out:
# Image Attention Map 1:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.442074)           …  HSV{Float32}(0.0,0.0,0.471034)
#  HSV{Float32}(60.0,0.00952381,0.438153)      HSV{Float32}(0.0,0.0,0.474955)
#  HSV{Float32}(60.0,0.00943396,0.442074)      HSV{Float32}(0.0,0.0,0.471034)
#  HSV{Float32}(60.0,0.00952381,0.438153)      HSV{Float32}(0.0,0.0,0.471034)
#  HSV{Float32}(60.0,0.00952381,0.438153)      HSV{Float32}(0.0,0.0,0.467112)
#  HSV{Float32}(0.0,0.0,0.442074)           …  HSV{Float32}(0.0,0.0,0.474955)
#  HSV{Float32}(0.0,0.0,0.442074)              HSV{Float32}(360.0,0.00970874,0.474955)
#  HSV{Float32}(0.0,0.0,0.442074)              HSV{Float32}(0.0,0.0,0.474955)
#  HSV{Float32}(0.0,0.0,0.438153)              HSV{Float32}(0.0,0.0,0.46319)
#  HSV{Float32}(0.0,0.0,0.438153)              HSV{Float32}(0.0,0.0,0.467112)
#  HSV{Float32}(0.0,0.0,0.438153)           …  HSV{Float32}(0.0,0.0,0.471034)
#  HSV{Float32}(0.0,0.0,0.438153)              HSV{Float32}(360.0,0.00970874,0.474955)
#  HSV{Float32}(0.0,0.0,0.442074)              HSV{Float32}(0.0,0.0,0.467112)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.624933)        HSV{Float32}(40.0,0.0422535,0.84913)
#  HSV{Float32}(30.0,0.017094,0.624933)        HSV{Float32}(40.0,0.0422535,0.84913)
#  HSV{Float32}(60.0,0.00862069,0.621011)   …  HSV{Float32}(40.0,0.041958,0.853052)
#  HSV{Float32}(360.0,0.00862069,0.621011)     HSV{Float32}(40.0,0.041958,0.853052)
#  HSV{Float32}(30.0,0.017094,0.624933)        HSV{Float32}(34.2857,0.048951,0.853052)
#  HSV{Float32}(30.0,0.0172414,0.621011)       HSV{Float32}(40.0,0.041958,0.853052)
#  HSV{Float32}(360.0,0.00862069,0.621011)     HSV{Float32}(34.2857,0.0486111,0.856973)
#  HSV{Float32}(30.0,0.017094,0.624933)     …  HSV{Float32}(40.0,0.041958,0.853052)
#  HSV{Float32}(30.0,0.017094,0.624933)        HSV{Float32}(40.0,0.041958,0.853052)
#  HSV{Float32}(360.0,0.00862069,0.621011)     HSV{Float32}(40.0,0.0416667,0.856973)
#  HSV{Float32}(30.0,0.0172414,0.621011)       HSV{Float32}(40.0,0.0416667,0.856973)
#  HSV{Float32}(30.0,0.0172414,0.621011)       HSV{Float32}(40.0,0.0416667,0.856973)
# 217×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 2:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.461775)           …  HSV{Float32}(0.0,0.0,0.461195)
#  HSV{Float32}(60.0,0.00952381,0.457854)      HSV{Float32}(0.0,0.0,0.465117)
#  HSV{Float32}(60.0,0.00943396,0.461775)      HSV{Float32}(0.0,0.0,0.461195)
#  HSV{Float32}(60.0,0.00952381,0.457854)      HSV{Float32}(0.0,0.0,0.461195)
#  HSV{Float32}(60.0,0.00952381,0.457854)      HSV{Float32}(0.0,0.0,0.457274)
#  HSV{Float32}(0.0,0.0,0.461775)           …  HSV{Float32}(0.0,0.0,0.465117)
#  HSV{Float32}(0.0,0.0,0.461775)              HSV{Float32}(360.0,0.00970874,0.465117)
#  HSV{Float32}(0.0,0.0,0.461775)              HSV{Float32}(0.0,0.0,0.465117)
#  HSV{Float32}(0.0,0.0,0.457854)              HSV{Float32}(0.0,0.0,0.453352)
#  HSV{Float32}(0.0,0.0,0.457854)              HSV{Float32}(0.0,0.0,0.457274)
#  HSV{Float32}(0.0,0.0,0.457854)           …  HSV{Float32}(0.0,0.0,0.461195)
#  HSV{Float32}(0.0,0.0,0.457854)              HSV{Float32}(360.0,0.00970874,0.465117)
#  HSV{Float32}(0.0,0.0,0.461775)              HSV{Float32}(0.0,0.0,0.457274)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.540462)        HSV{Float32}(40.0,0.0422535,0.718625)
#  HSV{Float32}(30.0,0.017094,0.540462)        HSV{Float32}(40.0,0.0422535,0.718625)
#  HSV{Float32}(60.0,0.00862069,0.536541)   …  HSV{Float32}(40.0,0.041958,0.722547)
#  HSV{Float32}(360.0,0.00862069,0.536541)     HSV{Float32}(40.0,0.041958,0.722547)
#  HSV{Float32}(30.0,0.017094,0.540462)        HSV{Float32}(34.2857,0.048951,0.722547)
#  HSV{Float32}(30.0,0.0172414,0.536541)       HSV{Float32}(40.0,0.041958,0.722547)
#  HSV{Float32}(360.0,0.00862069,0.536541)     HSV{Float32}(34.2857,0.0486111,0.726469)
#  HSV{Float32}(30.0,0.017094,0.540462)     …  HSV{Float32}(40.0,0.041958,0.722547)
#  HSV{Float32}(30.0,0.017094,0.540462)        HSV{Float32}(40.0,0.041958,0.722547)
#  HSV{Float32}(360.0,0.00862069,0.536541)     HSV{Float32}(40.0,0.0416667,0.726469)
#  HSV{Float32}(30.0,0.0172414,0.536541)       HSV{Float32}(40.0,0.0416667,0.726469)
#  HSV{Float32}(30.0,0.0172414,0.536541)       HSV{Float32}(40.0,0.0416667,0.726469)
# 247×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 3:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.42927)            …  HSV{Float32}(0.0,0.0,0.460267)
#  HSV{Float32}(60.0,0.00952381,0.425348)      HSV{Float32}(0.0,0.0,0.464189)
#  HSV{Float32}(60.0,0.00943396,0.42927)       HSV{Float32}(0.0,0.0,0.460267)
#  HSV{Float32}(60.0,0.00952381,0.425348)      HSV{Float32}(0.0,0.0,0.460267)
#  HSV{Float32}(60.0,0.00952381,0.425348)      HSV{Float32}(0.0,0.0,0.456345)
#  HSV{Float32}(0.0,0.0,0.42927)            …  HSV{Float32}(0.0,0.0,0.464189)
#  HSV{Float32}(0.0,0.0,0.42927)               HSV{Float32}(360.0,0.00970874,0.464189)
#  HSV{Float32}(0.0,0.0,0.42927)               HSV{Float32}(0.0,0.0,0.464189)
#  HSV{Float32}(0.0,0.0,0.425348)              HSV{Float32}(0.0,0.0,0.452424)
#  HSV{Float32}(0.0,0.0,0.425348)              HSV{Float32}(0.0,0.0,0.456345)
#  HSV{Float32}(0.0,0.0,0.425348)           …  HSV{Float32}(0.0,0.0,0.460267)
#  HSV{Float32}(0.0,0.0,0.425348)              HSV{Float32}(360.0,0.00970874,0.464189)
#  HSV{Float32}(0.0,0.0,0.42927)               HSV{Float32}(0.0,0.0,0.456345)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.62341)         HSV{Float32}(40.0,0.0422535,0.82279)
#  HSV{Float32}(30.0,0.017094,0.62341)         HSV{Float32}(40.0,0.0422535,0.82279)
#  HSV{Float32}(60.0,0.00862069,0.619489)   …  HSV{Float32}(40.0,0.041958,0.826712)
#  HSV{Float32}(360.0,0.00862069,0.619489)     HSV{Float32}(40.0,0.041958,0.826712)
#  HSV{Float32}(30.0,0.017094,0.62341)         HSV{Float32}(34.2857,0.048951,0.826712)
#  HSV{Float32}(30.0,0.0172414,0.619489)       HSV{Float32}(40.0,0.041958,0.826712)
#  HSV{Float32}(360.0,0.00862069,0.619489)     HSV{Float32}(34.2857,0.0486111,0.830633)
#  HSV{Float32}(30.0,0.017094,0.62341)      …  HSV{Float32}(40.0,0.041958,0.826712)
#  HSV{Float32}(30.0,0.017094,0.62341)         HSV{Float32}(40.0,0.041958,0.826712)
#  HSV{Float32}(360.0,0.00862069,0.619489)     HSV{Float32}(40.0,0.0416667,0.830633)
#  HSV{Float32}(30.0,0.0172414,0.619489)       HSV{Float32}(40.0,0.0416667,0.830633)
#  HSV{Float32}(30.0,0.0172414,0.619489)       HSV{Float32}(40.0,0.0416667,0.830633)
# 189×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 4:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.420957)           …  HSV{Float32}(0.0,0.0,0.424145)
#  HSV{Float32}(60.0,0.00952381,0.417035)      HSV{Float32}(0.0,0.0,0.428067)
#  HSV{Float32}(60.0,0.00943396,0.420957)      HSV{Float32}(0.0,0.0,0.424145)
#  HSV{Float32}(60.0,0.00952381,0.417035)      HSV{Float32}(0.0,0.0,0.424145)
#  HSV{Float32}(60.0,0.00952381,0.417035)      HSV{Float32}(0.0,0.0,0.420223)
#  HSV{Float32}(0.0,0.0,0.420957)           …  HSV{Float32}(0.0,0.0,0.428067)
#  HSV{Float32}(0.0,0.0,0.420957)              HSV{Float32}(360.0,0.00970874,0.428067)
#  HSV{Float32}(0.0,0.0,0.420957)              HSV{Float32}(0.0,0.0,0.428067)
#  HSV{Float32}(0.0,0.0,0.417035)              HSV{Float32}(0.0,0.0,0.416302)
#  HSV{Float32}(0.0,0.0,0.417035)              HSV{Float32}(0.0,0.0,0.420223)
#  HSV{Float32}(0.0,0.0,0.417035)           …  HSV{Float32}(0.0,0.0,0.424145)
#  HSV{Float32}(0.0,0.0,0.417035)              HSV{Float32}(360.0,0.00970874,0.428067)
#  HSV{Float32}(0.0,0.0,0.420957)              HSV{Float32}(0.0,0.0,0.420223)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.559373)        HSV{Float32}(40.0,0.0422535,1.0)
#  HSV{Float32}(30.0,0.017094,0.559373)        HSV{Float32}(40.0,0.0422535,1.0)
#  HSV{Float32}(60.0,0.00862069,0.555452)   …  HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(360.0,0.00862069,0.555452)     HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(30.0,0.017094,0.559373)        HSV{Float32}(34.2857,0.048951,1.0)
#  HSV{Float32}(30.0,0.0172414,0.555452)       HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(360.0,0.00862069,0.555452)     HSV{Float32}(34.2857,0.0486111,1.0)
#  HSV{Float32}(30.0,0.017094,0.559373)     …  HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(30.0,0.017094,0.559373)        HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(360.0,0.00862069,0.555452)     HSV{Float32}(40.0,0.0416667,1.0)
#  HSV{Float32}(30.0,0.0172414,0.555452)       HSV{Float32}(40.0,0.0416667,1.0)
#  HSV{Float32}(30.0,0.0172414,0.555452)       HSV{Float32}(40.0,0.0416667,1.0)
# 280×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 5:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.420128)           …  HSV{Float32}(0.0,0.0,0.422223)
#  HSV{Float32}(60.0,0.00952381,0.416206)      HSV{Float32}(0.0,0.0,0.426144)
#  HSV{Float32}(60.0,0.00943396,0.420128)      HSV{Float32}(0.0,0.0,0.422223)
#  HSV{Float32}(60.0,0.00952381,0.416206)      HSV{Float32}(0.0,0.0,0.422223)
#  HSV{Float32}(60.0,0.00952381,0.416206)      HSV{Float32}(0.0,0.0,0.418301)
#  HSV{Float32}(0.0,0.0,0.420128)           …  HSV{Float32}(0.0,0.0,0.426144)
#  HSV{Float32}(0.0,0.0,0.420128)              HSV{Float32}(360.0,0.00970874,0.426144)
#  HSV{Float32}(0.0,0.0,0.420128)              HSV{Float32}(0.0,0.0,0.426144)
#  HSV{Float32}(0.0,0.0,0.416206)              HSV{Float32}(0.0,0.0,0.41438)
#  HSV{Float32}(0.0,0.0,0.416206)              HSV{Float32}(0.0,0.0,0.418301)
#  HSV{Float32}(0.0,0.0,0.416206)           …  HSV{Float32}(0.0,0.0,0.422223)
#  HSV{Float32}(0.0,0.0,0.416206)              HSV{Float32}(360.0,0.00970874,0.426144)
#  HSV{Float32}(0.0,0.0,0.420128)              HSV{Float32}(0.0,0.0,0.418301)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.538754)        HSV{Float32}(40.0,0.0422535,0.916156)
#  HSV{Float32}(30.0,0.017094,0.538754)        HSV{Float32}(40.0,0.0422535,0.916156)
#  HSV{Float32}(60.0,0.00862069,0.534833)   …  HSV{Float32}(40.0,0.041958,0.920078)
#  HSV{Float32}(360.0,0.00862069,0.534833)     HSV{Float32}(40.0,0.041958,0.920078)
#  HSV{Float32}(30.0,0.017094,0.538754)        HSV{Float32}(34.2857,0.048951,0.920078)
#  HSV{Float32}(30.0,0.0172414,0.534833)       HSV{Float32}(40.0,0.041958,0.920078)
#  HSV{Float32}(360.0,0.00862069,0.534833)     HSV{Float32}(34.2857,0.0486111,0.923999)
#  HSV{Float32}(30.0,0.017094,0.538754)     …  HSV{Float32}(40.0,0.041958,0.920078)
#  HSV{Float32}(30.0,0.017094,0.538754)        HSV{Float32}(40.0,0.041958,0.920078)
#  HSV{Float32}(360.0,0.00862069,0.534833)     HSV{Float32}(40.0,0.0416667,0.923999)
#  HSV{Float32}(30.0,0.0172414,0.534833)       HSV{Float32}(40.0,0.0416667,0.923999)
#  HSV{Float32}(30.0,0.0172414,0.534833)       HSV{Float32}(40.0,0.0416667,0.923999)
# 310×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 6:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.447517)           …  HSV{Float32}(0.0,0.0,0.534157)
#  HSV{Float32}(60.0,0.00952381,0.443595)      HSV{Float32}(0.0,0.0,0.538079)
#  HSV{Float32}(60.0,0.00943396,0.447517)      HSV{Float32}(0.0,0.0,0.534157)
#  HSV{Float32}(60.0,0.00952381,0.443595)      HSV{Float32}(0.0,0.0,0.534157)
#  HSV{Float32}(60.0,0.00952381,0.443595)      HSV{Float32}(0.0,0.0,0.530235)
#  HSV{Float32}(0.0,0.0,0.447517)           …  HSV{Float32}(0.0,0.0,0.538079)
#  HSV{Float32}(0.0,0.0,0.447517)              HSV{Float32}(360.0,0.00970874,0.538079)
#  HSV{Float32}(0.0,0.0,0.447517)              HSV{Float32}(0.0,0.0,0.538079)
#  HSV{Float32}(0.0,0.0,0.443595)              HSV{Float32}(0.0,0.0,0.526314)
#  HSV{Float32}(0.0,0.0,0.443595)              HSV{Float32}(0.0,0.0,0.530235)
#  HSV{Float32}(0.0,0.0,0.443595)           …  HSV{Float32}(0.0,0.0,0.534157)
#  HSV{Float32}(0.0,0.0,0.443595)              HSV{Float32}(360.0,0.00970874,0.538079)
#  HSV{Float32}(0.0,0.0,0.447517)              HSV{Float32}(0.0,0.0,0.530235)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.508799)        HSV{Float32}(40.0,0.0422535,0.630136)
#  HSV{Float32}(30.0,0.017094,0.508799)        HSV{Float32}(40.0,0.0422535,0.630136)
#  HSV{Float32}(60.0,0.00862069,0.504878)   …  HSV{Float32}(40.0,0.041958,0.634058)
#  HSV{Float32}(360.0,0.00862069,0.504878)     HSV{Float32}(40.0,0.041958,0.634058)
#  HSV{Float32}(30.0,0.017094,0.508799)        HSV{Float32}(34.2857,0.048951,0.634058)
#  HSV{Float32}(30.0,0.0172414,0.504878)       HSV{Float32}(40.0,0.041958,0.634058)
#  HSV{Float32}(360.0,0.00862069,0.504878)     HSV{Float32}(34.2857,0.0486111,0.637979)
#  HSV{Float32}(30.0,0.017094,0.508799)     …  HSV{Float32}(40.0,0.041958,0.634058)
#  HSV{Float32}(30.0,0.017094,0.508799)        HSV{Float32}(40.0,0.041958,0.634058)
#  HSV{Float32}(360.0,0.00862069,0.504878)     HSV{Float32}(40.0,0.0416667,0.637979)
#  HSV{Float32}(30.0,0.0172414,0.504878)       HSV{Float32}(40.0,0.0416667,0.637979)
#  HSV{Float32}(30.0,0.0172414,0.504878)       HSV{Float32}(40.0,0.0416667,0.637979)
# 274×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 7:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.444824)           …  HSV{Float32}(0.0,0.0,0.555497)
#  HSV{Float32}(60.0,0.00952381,0.440903)      HSV{Float32}(0.0,0.0,0.559419)
#  HSV{Float32}(60.0,0.00943396,0.444824)      HSV{Float32}(0.0,0.0,0.555497)
#  HSV{Float32}(60.0,0.00952381,0.440903)      HSV{Float32}(0.0,0.0,0.555497)
#  HSV{Float32}(60.0,0.00952381,0.440903)      HSV{Float32}(0.0,0.0,0.551576)
#  HSV{Float32}(0.0,0.0,0.444824)           …  HSV{Float32}(0.0,0.0,0.559419)
#  HSV{Float32}(0.0,0.0,0.444824)              HSV{Float32}(360.0,0.00970874,0.559419)
#  HSV{Float32}(0.0,0.0,0.444824)              HSV{Float32}(0.0,0.0,0.559419)
#  HSV{Float32}(0.0,0.0,0.440903)              HSV{Float32}(0.0,0.0,0.547654)
#  HSV{Float32}(0.0,0.0,0.440903)              HSV{Float32}(0.0,0.0,0.551576)
#  HSV{Float32}(0.0,0.0,0.440903)           …  HSV{Float32}(0.0,0.0,0.555497)
#  HSV{Float32}(0.0,0.0,0.440903)              HSV{Float32}(360.0,0.00970874,0.559419)
#  HSV{Float32}(0.0,0.0,0.444824)              HSV{Float32}(0.0,0.0,0.551576)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.672934)        HSV{Float32}(40.0,0.0422535,0.625712)
#  HSV{Float32}(30.0,0.017094,0.672934)        HSV{Float32}(40.0,0.0422535,0.625712)
#  HSV{Float32}(60.0,0.00862069,0.669013)   …  HSV{Float32}(40.0,0.041958,0.629634)
#  HSV{Float32}(360.0,0.00862069,0.669013)     HSV{Float32}(40.0,0.041958,0.629634)
#  HSV{Float32}(30.0,0.017094,0.672934)        HSV{Float32}(34.2857,0.048951,0.629634)
#  HSV{Float32}(30.0,0.0172414,0.669013)       HSV{Float32}(40.0,0.041958,0.629634)
#  HSV{Float32}(360.0,0.00862069,0.669013)     HSV{Float32}(34.2857,0.0486111,0.633555)
#  HSV{Float32}(30.0,0.017094,0.672934)     …  HSV{Float32}(40.0,0.041958,0.629634)
#  HSV{Float32}(30.0,0.017094,0.672934)        HSV{Float32}(40.0,0.041958,0.629634)
#  HSV{Float32}(360.0,0.00862069,0.669013)     HSV{Float32}(40.0,0.0416667,0.633555)
#  HSV{Float32}(30.0,0.0172414,0.669013)       HSV{Float32}(40.0,0.0416667,0.633555)
#  HSV{Float32}(30.0,0.0172414,0.669013)       HSV{Float32}(40.0,0.0416667,0.633555)
# 317×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 8:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.439504)           …  HSV{Float32}(0.0,0.0,0.604574)
#  HSV{Float32}(60.0,0.00952381,0.435582)      HSV{Float32}(0.0,0.0,0.608496)
#  HSV{Float32}(60.0,0.00943396,0.439504)      HSV{Float32}(0.0,0.0,0.604574)
#  HSV{Float32}(60.0,0.00952381,0.435582)      HSV{Float32}(0.0,0.0,0.604574)
#  HSV{Float32}(60.0,0.00952381,0.435582)      HSV{Float32}(0.0,0.0,0.600652)
#  HSV{Float32}(0.0,0.0,0.439504)           …  HSV{Float32}(0.0,0.0,0.608496)
#  HSV{Float32}(0.0,0.0,0.439504)              HSV{Float32}(360.0,0.00970874,0.608496)
#  HSV{Float32}(0.0,0.0,0.439504)              HSV{Float32}(0.0,0.0,0.608496)
#  HSV{Float32}(0.0,0.0,0.435582)              HSV{Float32}(0.0,0.0,0.596731)
#  HSV{Float32}(0.0,0.0,0.435582)              HSV{Float32}(0.0,0.0,0.600652)
#  HSV{Float32}(0.0,0.0,0.435582)           …  HSV{Float32}(0.0,0.0,0.604574)
#  HSV{Float32}(0.0,0.0,0.435582)              HSV{Float32}(360.0,0.00970874,0.608496)
#  HSV{Float32}(0.0,0.0,0.439504)              HSV{Float32}(0.0,0.0,0.600652)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.656052)        HSV{Float32}(40.0,0.0422535,0.622991)
#  HSV{Float32}(30.0,0.017094,0.656052)        HSV{Float32}(40.0,0.0422535,0.622991)
#  HSV{Float32}(60.0,0.00862069,0.652131)   …  HSV{Float32}(40.0,0.041958,0.626913)
#  HSV{Float32}(360.0,0.00862069,0.652131)     HSV{Float32}(40.0,0.041958,0.626913)
#  HSV{Float32}(30.0,0.017094,0.656052)        HSV{Float32}(34.2857,0.048951,0.626913)
#  HSV{Float32}(30.0,0.0172414,0.652131)       HSV{Float32}(40.0,0.041958,0.626913)
#  HSV{Float32}(360.0,0.00862069,0.652131)     HSV{Float32}(34.2857,0.0486111,0.630834)
#  HSV{Float32}(30.0,0.017094,0.656052)     …  HSV{Float32}(40.0,0.041958,0.626913)
#  HSV{Float32}(30.0,0.017094,0.656052)        HSV{Float32}(40.0,0.041958,0.626913)
#  HSV{Float32}(360.0,0.00862069,0.652131)     HSV{Float32}(40.0,0.0416667,0.630834)
#  HSV{Float32}(30.0,0.0172414,0.652131)       HSV{Float32}(40.0,0.0416667,0.630834)
#  HSV{Float32}(30.0,0.0172414,0.652131)       HSV{Float32}(40.0,0.0416667,0.630834)
# 160×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 9:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.457796)           …  HSV{Float32}(0.0,0.0,0.443935)
#  HSV{Float32}(60.0,0.00952381,0.453875)      HSV{Float32}(0.0,0.0,0.447856)
#  HSV{Float32}(60.0,0.00943396,0.457796)      HSV{Float32}(0.0,0.0,0.443935)
#  HSV{Float32}(60.0,0.00952381,0.453875)      HSV{Float32}(0.0,0.0,0.443935)
#  HSV{Float32}(60.0,0.00952381,0.453875)      HSV{Float32}(0.0,0.0,0.440013)
#  HSV{Float32}(0.0,0.0,0.457796)           …  HSV{Float32}(0.0,0.0,0.447856)
#  HSV{Float32}(0.0,0.0,0.457796)              HSV{Float32}(360.0,0.00970874,0.447856)
#  HSV{Float32}(0.0,0.0,0.457796)              HSV{Float32}(0.0,0.0,0.447856)
#  HSV{Float32}(0.0,0.0,0.453875)              HSV{Float32}(0.0,0.0,0.436092)
#  HSV{Float32}(0.0,0.0,0.453875)              HSV{Float32}(0.0,0.0,0.440013)
#  HSV{Float32}(0.0,0.0,0.453875)           …  HSV{Float32}(0.0,0.0,0.443935)
#  HSV{Float32}(0.0,0.0,0.453875)              HSV{Float32}(360.0,0.00970874,0.447856)
#  HSV{Float32}(0.0,0.0,0.457796)              HSV{Float32}(0.0,0.0,0.440013)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.772518)        HSV{Float32}(40.0,0.0422535,1.0)
#  HSV{Float32}(30.0,0.017094,0.772518)        HSV{Float32}(40.0,0.0422535,1.0)
#  HSV{Float32}(60.0,0.00862069,0.768597)   …  HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(360.0,0.00862069,0.768597)     HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(30.0,0.017094,0.772518)        HSV{Float32}(34.2857,0.048951,1.0)
#  HSV{Float32}(30.0,0.0172414,0.768597)       HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(360.0,0.00862069,0.768597)     HSV{Float32}(34.2857,0.0486111,1.0)
#  HSV{Float32}(30.0,0.017094,0.772518)     …  HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(30.0,0.017094,0.772518)        HSV{Float32}(40.0,0.041958,1.0)
#  HSV{Float32}(360.0,0.00862069,0.768597)     HSV{Float32}(40.0,0.0416667,1.0)
#  HSV{Float32}(30.0,0.0172414,0.768597)       HSV{Float32}(40.0,0.0416667,1.0)
#  HSV{Float32}(30.0,0.0172414,0.768597)       HSV{Float32}(40.0,0.0416667,1.0)
# 229×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 10:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.58182)            …  HSV{Float32}(0.0,0.0,0.514973)
#  HSV{Float32}(60.0,0.00952381,0.577899)      HSV{Float32}(0.0,0.0,0.518895)
#  HSV{Float32}(60.0,0.00943396,0.58182)       HSV{Float32}(0.0,0.0,0.514973)
#  HSV{Float32}(60.0,0.00952381,0.577899)      HSV{Float32}(0.0,0.0,0.514973)
#  HSV{Float32}(60.0,0.00952381,0.577899)      HSV{Float32}(0.0,0.0,0.511052)
#  HSV{Float32}(0.0,0.0,0.58182)            …  HSV{Float32}(0.0,0.0,0.518895)
#  HSV{Float32}(0.0,0.0,0.58182)               HSV{Float32}(360.0,0.00970874,0.518895)
#  HSV{Float32}(0.0,0.0,0.58182)               HSV{Float32}(0.0,0.0,0.518895)
#  HSV{Float32}(0.0,0.0,0.577899)              HSV{Float32}(0.0,0.0,0.50713)
#  HSV{Float32}(0.0,0.0,0.577899)              HSV{Float32}(0.0,0.0,0.511052)
#  HSV{Float32}(0.0,0.0,0.577899)           …  HSV{Float32}(0.0,0.0,0.514973)
#  HSV{Float32}(0.0,0.0,0.577899)              HSV{Float32}(360.0,0.00970874,0.518895)
#  HSV{Float32}(0.0,0.0,0.58182)               HSV{Float32}(0.0,0.0,0.511052)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.582791)        HSV{Float32}(40.0,0.0422535,0.825186)
#  HSV{Float32}(30.0,0.017094,0.582791)        HSV{Float32}(40.0,0.0422535,0.825186)
#  HSV{Float32}(60.0,0.00862069,0.578869)   …  HSV{Float32}(40.0,0.041958,0.829108)
#  HSV{Float32}(360.0,0.00862069,0.578869)     HSV{Float32}(40.0,0.041958,0.829108)
#  HSV{Float32}(30.0,0.017094,0.582791)        HSV{Float32}(34.2857,0.048951,0.829108)
#  HSV{Float32}(30.0,0.0172414,0.578869)       HSV{Float32}(40.0,0.041958,0.829108)
#  HSV{Float32}(360.0,0.00862069,0.578869)     HSV{Float32}(34.2857,0.0486111,0.83303)
#  HSV{Float32}(30.0,0.017094,0.582791)     …  HSV{Float32}(40.0,0.041958,0.829108)
#  HSV{Float32}(30.0,0.017094,0.582791)        HSV{Float32}(40.0,0.041958,0.829108)
#  HSV{Float32}(360.0,0.00862069,0.578869)     HSV{Float32}(40.0,0.0416667,0.83303)
#  HSV{Float32}(30.0,0.0172414,0.578869)       HSV{Float32}(40.0,0.0416667,0.83303)
#  HSV{Float32}(30.0,0.0172414,0.578869)       HSV{Float32}(40.0,0.0416667,0.83303)
# 231×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 11:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.56174)            …  HSV{Float32}(0.0,0.0,0.556949)
#  HSV{Float32}(60.0,0.00952381,0.557818)      HSV{Float32}(0.0,0.0,0.56087)
#  HSV{Float32}(60.0,0.00943396,0.56174)       HSV{Float32}(0.0,0.0,0.556949)
#  HSV{Float32}(60.0,0.00952381,0.557818)      HSV{Float32}(0.0,0.0,0.556949)
#  HSV{Float32}(60.0,0.00952381,0.557818)      HSV{Float32}(0.0,0.0,0.553027)
#  HSV{Float32}(0.0,0.0,0.56174)            …  HSV{Float32}(0.0,0.0,0.56087)
#  HSV{Float32}(0.0,0.0,0.56174)               HSV{Float32}(360.0,0.00970874,0.56087)
#  HSV{Float32}(0.0,0.0,0.56174)               HSV{Float32}(0.0,0.0,0.56087)
#  HSV{Float32}(0.0,0.0,0.557818)              HSV{Float32}(0.0,0.0,0.549105)
#  HSV{Float32}(0.0,0.0,0.557818)              HSV{Float32}(0.0,0.0,0.553027)
#  HSV{Float32}(0.0,0.0,0.557818)           …  HSV{Float32}(0.0,0.0,0.556949)
#  HSV{Float32}(0.0,0.0,0.557818)              HSV{Float32}(360.0,0.00970874,0.56087)
#  HSV{Float32}(0.0,0.0,0.56174)               HSV{Float32}(0.0,0.0,0.553027)
#  ⋮                                        ⋱
#  HSV{Float32}(30.0,0.017094,0.597137)        HSV{Float32}(40.0,0.0422535,0.72637)
#  HSV{Float32}(30.0,0.017094,0.597137)        HSV{Float32}(40.0,0.0422535,0.72637)
#  HSV{Float32}(60.0,0.00862069,0.593215)   …  HSV{Float32}(40.0,0.041958,0.730291)
#  HSV{Float32}(360.0,0.00862069,0.593215)     HSV{Float32}(40.0,0.041958,0.730291)
#  HSV{Float32}(30.0,0.017094,0.597137)        HSV{Float32}(34.2857,0.048951,0.730291)
#  HSV{Float32}(30.0,0.0172414,0.593215)       HSV{Float32}(40.0,0.041958,0.730291)
#  HSV{Float32}(360.0,0.00862069,0.593215)     HSV{Float32}(34.2857,0.0486111,0.734213)
#  HSV{Float32}(30.0,0.017094,0.597137)     …  HSV{Float32}(40.0,0.041958,0.730291)
#  HSV{Float32}(30.0,0.017094,0.597137)        HSV{Float32}(40.0,0.041958,0.730291)
#  HSV{Float32}(360.0,0.00862069,0.593215)     HSV{Float32}(40.0,0.0416667,0.734213)
#  HSV{Float32}(30.0,0.0172414,0.593215)       HSV{Float32}(40.0,0.0416667,0.734213)
#  HSV{Float32}(30.0,0.0172414,0.593215)       HSV{Float32}(40.0,0.0416667,0.734213)
# 203×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# Image Attention Map 12:
# 320×480 Array{HSV{Float32},2} with eltype HSV{Float32}:
#  HSV{Float32}(0.0,0.0,0.542534)          …  HSV{Float32}(0.0,0.0,0.587889)
#  HSV{Float32}(60.0,0.00952381,0.538613)     HSV{Float32}(0.0,0.0,0.59181)
#  HSV{Float32}(60.0,0.00943396,0.542534)     HSV{Float32}(0.0,0.0,0.587889)
#  HSV{Float32}(60.0,0.00952381,0.538613)     HSV{Float32}(0.0,0.0,0.587889)
#  HSV{Float32}(60.0,0.00952381,0.538613)     HSV{Float32}(0.0,0.0,0.583967)
#  HSV{Float32}(0.0,0.0,0.542534)          …  HSV{Float32}(0.0,0.0,0.59181)
#  HSV{Float32}(0.0,0.0,0.542534)             HSV{Float32}(360.0,0.00970874,0.59181)
#  HSV{Float32}(0.0,0.0,0.542534)             HSV{Float32}(0.0,0.0,0.59181)
#  HSV{Float32}(0.0,0.0,0.538613)             HSV{Float32}(0.0,0.0,0.580045)
#  HSV{Float32}(0.0,0.0,0.538613)             HSV{Float32}(0.0,0.0,0.583967)
#  HSV{Float32}(0.0,0.0,0.538613)          …  HSV{Float32}(0.0,0.0,0.587889)
#  HSV{Float32}(0.0,0.0,0.538613)             HSV{Float32}(360.0,0.00970874,0.59181)
#  HSV{Float32}(0.0,0.0,0.542534)             HSV{Float32}(0.0,0.0,0.583967)
#  ⋮                                       ⋱
#  HSV{Float32}(30.0,0.017094,0.572252)       HSV{Float32}(40.0,0.0422535,0.737939)
#  HSV{Float32}(30.0,0.017094,0.572252)       HSV{Float32}(40.0,0.0422535,0.737939)
#  HSV{Float32}(60.0,0.00862069,0.56833)   …  HSV{Float32}(40.0,0.041958,0.74186)
#  HSV{Float32}(360.0,0.00862069,0.56833)     HSV{Float32}(40.0,0.041958,0.74186)
#  HSV{Float32}(30.0,0.017094,0.572252)       HSV{Float32}(34.2857,0.048951,0.74186)
#  HSV{Float32}(30.0,0.0172414,0.56833)       HSV{Float32}(40.0,0.041958,0.74186)
#  HSV{Float32}(360.0,0.00862069,0.56833)     HSV{Float32}(34.2857,0.0486111,0.745782)
#  HSV{Float32}(30.0,0.017094,0.572252)    …  HSV{Float32}(40.0,0.041958,0.74186)
#  HSV{Float32}(30.0,0.017094,0.572252)       HSV{Float32}(40.0,0.041958,0.74186)
#  HSV{Float32}(360.0,0.00862069,0.56833)     HSV{Float32}(40.0,0.0416667,0.745782)
#  HSV{Float32}(30.0,0.0172414,0.56833)       HSV{Float32}(40.0,0.0416667,0.745782)
#  HSV{Float32}(30.0,0.0172414,0.56833)       HSV{Float32}(40.0,0.0416667,0.745782)
# 168×600 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                                               ⋱
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
