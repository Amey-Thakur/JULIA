# %% [markdown]
# # Character based RNN language model
# Based on http://karpathy.github.io/2015/05/21/rnn-effectiveness

# %% [markdown]
# ## Setup
# 1-Adds required packages to Julia.
# 2-Loads the data and a pretrained model.

# %%
include("charlm.jl")
# Out:
# ┌ Info: Loading Shakespeare data
# └ @ Main /home/gridsan/dyuret/NLPdemos/charlm/charlm.jl:48
# ┌ Info: Loading Shakespeare model
# └ @ Main /home/gridsan/dyuret/NLPdemos/charlm/charlm.jl:53
# ┌ Info: Reading Julia files
# └ @ Main /home/gridsan/dyuret/NLPdemos/charlm/charlm.jl:57
# ┌ Info: Loading Julia model
# └ @ Main /home/gridsan/dyuret/NLPdemos/charlm/charlm.jl:69

# %% [markdown]
# ## Sample Data-1
# A random subset of the Shakespeare training data

# %%
LEN = 500
r = rand(1:length(shake_text)-LEN)
println(shake_text[r:r+LEN])
flush(stdout)
# Out:
# y villainy
#     I got this ring; 'twas Leonatus' jewel,
#     Whom thou didst banish; and- which more may grieve thee,
#     As it doth me- a nobler sir ne'er liv'd
#     'Twixt sky and ground. Wilt thou hear more, my lord?
#   CYMBELINE. All that belongs to this.
#   IACHIMO. That paragon, thy daughter,
#     For whom my heart drops blood and my false spirits
#     Quail to remember- Give me leave, I faint.
#   CYMBELINE. My daughter? What of her? Renew thy strength;
#     I had rather thou shouldst live

# %% [markdown]
# ## Sample Generation-1
# Random Shakespeare style text generated by the model

# %%
generate(shake_model, shake_chars, LEN)
# Out:
# ADjey? Well?
# thine mend upward dismiss of a Cortio.
#
# Enter CRAUDSER,          "
#   LORDS, EARON bitingual.
#                                      [Drans the court]
#   FAETER. People! Frail some father Bullty, will you suncen?
#   DUCHESS. See' to alt thought to break our windance,
#     Which I dote chird.
#   MERCHANT. Douth me for my remain'd, sir; my lord; I know
#     O, when he holds unto my sistress! First,
#     They are supplated heaven such batts.
#   BANQUO. And fear your albosity spare ou

# %% [markdown]
# ## Sample Data-2
# A random subset of the code in Julia base

# %%
r = rand(1:length(julia_text)-LEN)
println(julia_text[r:r+LEN])
flush(stdout)
# Out:
#         return env
#     end
#     return false
# end
#
# function project_deps_get(env::String, name::String)::Union{Bool,UUID}
#     project_file = env_project_file(env)
#     if project_file isa String
#         return explicit_project_deps_get(project_file, name)
#     end
#     project_file && implicit_project_deps_get(env, name)
# end
#
# function manifest_deps_get(env::String, where::PkgId, name::String)::Union{Bool,UUID}
#     @assert where.uuid !== nothing
#     project_file = env_project_file(env)
#     if project_f

# %% [markdown]
# ## Sample Generation-2
# Random Julia code generated by the model

# %%
generate(julia_model, julia_chars, LEN)
# Out:
#             # solver cases, but
#      #  category or "^ gc = ", log_event_maybebuint6477(),
#                    localer(false), mod_1)
#         # Add packages for lower StringMutabString
#         # the last since block for definition
#         let d9 = get_empty_fetch!(gc_num)
#             # line meta
#         end
#     end
# end
# test_meta(dt) = Float64
# @test doubly_declared_floor(x) == 1 - 2
#
# # Cannot be preserving array.
# @test convert(Tuple{Any}, typeof(tss2)) == Union{BitSigned,LowerTrie}
# @test doubly_in
